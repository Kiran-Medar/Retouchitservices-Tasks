# %%
speed = float(input("Enter speed of the vehicle: "))
time = float(input("Enter time traveled: "))

# Calculate distance
distance = speed * time
print("Distance covered by the vehicle:", distance)
# Out:
# Enter speed of the vehicle:  30
# Enter time traveled:  20
# Distance covered by the vehicle: 600.0
